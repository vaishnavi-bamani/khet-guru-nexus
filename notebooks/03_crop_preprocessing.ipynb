# %% [markdown]
# # 🌾 KhetGuru Nexus
#
# # Crop Recommendation Module
#
# ## Notebook 03 : Data Preprocessing
#
# ### 🎯 Objective
#
# The objective of this notebook is to prepare the crop recommendation dataset for machine learning.
#
# This notebook includes:
#
# - Feature Selection
# - Target Selection
# - Label Encoding
# - Train-Test Split
# - Feature Scaling (Discussion)
# - Dataset Ready for Model Training

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Feature and Target Selection
#
# Machine learning models require input features (X) and target labels (y).
#
# In this project:
#
# Features = Soil and Weather Parameters
#
# Target = Crop Label

# %%
X = df.drop("label", axis=1)

y = df["label"]

print("Feature Shape :", X.shape)
print("Target Shape :", y.shape)

# %% [markdown]
# ## Observation
#
# The dataset has been divided into:
#
# - X (Input Features)
# - y (Target Variable)
#
# The machine learning model will learn the relationship between X and y.

# %%
# Label Encoding

Machine learning models cannot understand text labels directly.

Therefore, crop names are converted into numerical values using Label Encoding.

# %%
encoder = LabelEncoder()

y_encoded = encoder.fit_transform(y)

print(y_encoded[:20])

# %%
mapping = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))

mapping

# %% [markdown]
# ## Observation
#
# Each crop has been assigned a unique numerical label.
#
# These encoded values will be used during model training.

# %% [markdown]
# # Train-Test Split
#
# The dataset is divided into two parts:
#
# Training Set
#
# Used to train the model.
#
# Testing Set
#
# Used to evaluate the model on unseen data.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,
    test_size=0.2,
    random_state=42
)

print("Training Samples :", X_train.shape)
print("Testing Samples :", X_test.shape)

# %% [markdown]
# ## Why 80-20 Split?
#
# 80% of the data is used to train the model.
#
# 20% is reserved for evaluating how well the model performs on unseen data.

# %% [markdown]
# # Feature Scaling
#
# Feature scaling transforms numerical values to a similar range.
#
# Examples include:
#
# - StandardScaler
# - MinMaxScaler
#
# ### Note
#
# For this project, Random Forest does not require feature scaling because it is a tree-based algorithm.
#
# Therefore, scaling is skipped.

# %% [markdown]
# # Conclusion
#
# The dataset has been successfully prepared for machine learning.
#
# Completed steps:
#
# - Loaded Dataset
# - Selected Features and Target
# - Encoded Crop Labels
# - Split Data into Training and Testing Sets
#
# The dataset is now ready for model training.
